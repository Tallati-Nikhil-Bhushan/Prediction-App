# %%
import os
import keras
from keras.models import Sequential,load_model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[1], [0]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %%
data = []
paths = []
result = []

for r, d, f in os.walk(r'../Datasets/Brain_tumor_dataset/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../Datasets/Brain_tumor_dataset/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (BatchN  (None, 128, 128, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 5s 1s/step - loss: 81.6013 - val_loss: 84.7226
# Epoch 2/30
# 3/3 [==============================] - 4s 1s/step - loss: 17.9522 - val_loss: 77.7380
# Epoch 3/30
# 3/3 [==============================] - 4s 1s/step - loss: 17.2270 - val_loss: 12.5334
# Epoch 4/30
# 3/3 [==============================] - 3s 923ms/step - loss: 2.9215 - val_loss: 7.8920
# Epoch 5/30
# 3/3 [==============================] - 3s 1s/step - loss: 4.5801 - val_loss: 8.7876
# Epoch 6/30
# 3/3 [==============================] - 4s 1s/step - loss: 3.6436 - val_loss: 4.1747
# Epoch 7/30
# 3/3 [==============================] - 4s 1s/step - loss: 1.3098 - val_loss: 2.1836
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.3150 - val_loss: 3.5527
# Epoch 9/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.6780 - val_loss: 2.9428
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.0305 - val_loss: 2.5047
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.2461 - val_loss: 3.7694
# Epoch 12/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.5099 - val_loss: 4.0885
# Epoch 13/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.4778 - val_loss: 3.3765
# Epoch 14/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.3311 - val_loss: 2.6954
# Epoch 15/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.1493 - val_loss: 2.4746
# Epoch 16/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.3288 - val_loss: 2.5853
# Epoch 17/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1481 - val_loss: 2.5935
# Epoch 18/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1260 - val_loss: 2.5294
# Epoch 19/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0630 - val_loss: 2.4470
# Epoch 20/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0471 - val_loss: 2.3750
# Epoch 21/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0389 - val_loss: 2.3303
# Epoch 22/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0771 - val_loss: 2.3000
# Epoch 23/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0244 - val_loss: 2.2808
# Epoch 24/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0300 - val_loss: 2.2663
# Epoch 25/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0248 - val_loss: 2.2696
# Epoch 26/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.0351 - val_loss: 2.2765
# Epoch 27/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0632 - val_loss: 2.2546
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0306 - val_loss: 2.2435
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0328 - val_loss: 2.2464
# Epoch 30/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0124 - val_loss: 2.2474

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==1:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../Datasets/Brain_tumor_dataset/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 99.99903440475464% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../Datasets/Brain_tumor_dataset/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 95.69540023803711% Confidence This Is A Its a Tumor

# %%
model.save("../prediction_models/brain_tumor.h5")

# %%
from keras.models import load_model

loaded_model = load_model('../prediction_models/brain_tumor.h5')

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../Datasets/Brain_tumor_dataset/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = loaded_model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 99.99903440475464% Confidence This Is No, Its not a tumor
